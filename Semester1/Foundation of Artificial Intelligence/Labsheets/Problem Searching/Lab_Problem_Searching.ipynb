# %% [markdown]
# # Breadth First Search - BFS

# %%
from queue import Queue
adj_list = {
    "5": ["3", "7"],   
    "3": ["2", "4"],  
    "7": ["8"],
    "2": [],
    "4": ["8"],
    "8": []
}

visited = {}    # dict
parent = {}
bfs_traversal_order =[]  # lst
queue = Queue()   

for node in adj_list.keys():
    visited[node] = False  
    parent[node] = None  
s = "5" 
visited[s] = True  
queue.put(s)  


while not queue.empty():
    u = queue.get()  
    bfs_traversal_order.append(u)      
    for v in adj_list[u]:   
        if not visited[v]:        
            visited[v] = True       
            parent[v] = u            
            queue.put(v)            
            
print("BFS Traversal Order  : ")
print(bfs_traversal_order)           

destination = "8"
path = []
while destination is not None:
    path.append(destination)
    destination = parent[destination]
path.reverse()
print("Path : ")
print(path)
# Out:
# BFS Traversal Order  :
# ['5', '3', '7', '2', '4', '8']
# Path :
# ['5', '7', '8']

# %% [markdown]
# # Deapth First Search - DFS

# %%
adj_list = {
    "5": ["3", "7"],   
    "3": ["2", "4"],  
    "7": ["8"],
    "2": [],
    "4": ["8"],
    "8": []
}

color = {}    
parent = {}  
dfs_traversal_order = [] 

for node in adj_list.keys():
    color[node] = "W"
    parent[node]= None

def dfs_util(u): 
    color[u] =  "G"
    dfs_traversal_order.append(u)
    
    for v in adj_list[u]:
        if color[v] == "W": 
            parent[v] = u 
            dfs_util(v)
    color[u] = "B" 
    

dfs_util("5")
print("dfs_traversal_order :")
print(dfs_traversal_order)

v = "8"
path = []
while v is not None:
    path.append(v)
    v = parent[v]
path.reverse()
print("Path: ")
print(path)
# Out:
# dfs_traversal_order :
# ['5', '3', '2', '4', '8', '7']
# Path:
# ['5', '3', '4', '8']

# %% [markdown]
# # UCS

# %%
def uniform_cost_search(goal, start, path):
    
    global graph, cost
    answer = []
    
    queue = []
    
    for i in range(len(goal)): 
        answer.append(10**8)
        
    queue.append([0, start])
    parent = []
    vtd = []
    vtd.append(start) 
    parent.append(start)
    visited = {}
    
    count = 0
    
    while (len(queue) > 0):
        queue = sorted(queue) 
        p = queue[-1]
        
        
        del queue[-1]
        
        p[0] *= -1
        path.append(p[1])
        
        if (p[1] in goal):
            
            index = goal.index(p[1])
            
            if (answer[index] == 10**8):
                count += 1
                
            if (answer[index] > p[0]):
                answer[index] = p[0]
                
                
            del queue[-1]
            
            
            queue = sorted(queue) 
            if (count == len(goal)):
                return answer
            
        
        if (p[1] not in visited): 
            for i in range(len(graph[p[1]])):
                queue.append( [(p[0] + cost[(p[1], graph[p[1]][i])])* -1, graph[p[1]][i]])
                
        visited[p[1]] = 1
    
    return answer

#main function
if __name__ == '__main__':
    
    graph,cost = [[] for i in range(8)],{}
    
    
    graph[0].append(1) 
    graph[0].append(2)
    graph[0].append(3)
    graph[1].append(4)
    graph [2].append(5)
    graph[4].append(5) 
    graph[5].append(6)
    graph[4].append(6)
    graph[3].append(6)
          
          
    
    cost[(0, 1)]  = 3
    cost[(1, 4)]  = 5
    cost[(4, 6)]  = 8
    cost[(0, 2)]  = 2
    cost[(2, 5)]  = 1
    cost[(4, 5)]  = 2
    cost[(5, 6)]  = 6
    cost[(0, 3)]  = 5
    cost[(3, 6)]  = 9
    
    
    goal = []
    goal.append(6)
    path = [] 
    answer = uniform_cost_search(goal, 0,path) 
    print("Minimum cost from 0 to 6 is = ", answer[0]) 
    print(path)

# %% [markdown]
# # Best First Search

# %%
from queue import PriorityQueue
v = 5                                      
graph = [[] for i in range(v)]           

def bestfs(act_source,target,n):         
    parent = []
    vtd = []                                 
    visited = [False]*n
    pq = PriorityQueue()
    pq.put((0,act_source))                   #cost,source
    vtd.append(act_source)                   
    parent.append(act_source)                 
    visited[act_source] = True
    
    while pq.empty() == False:
        u = pq.get()[1]                       
        
        if u == target:                        
            l = []
            x = target
            l.append(target)
            while x!= act_source:            
                index = vtd.index(x)           
                p = parent[index]
                l.append(p)
                x = p
            l.reverse()
            print(l)
            break
        
        for v,c in graph[u]:
            if visited[v] == False:
                vtd.append(v)
                parent.append(u)
                visited[v] = True
                pq.put((c,v))
                
def addedge(x,y,cost):
    graph[x].append((y,cost))
    graph[y].append((x,cost))
    
addedge(0, 1, 5)
addedge(0, 2, 1)
addedge(2, 3, 2)
addedge(1, 4, 1)
addedge(3, 4, 2)
source = 0
target = 4

bestfs(source,target,v)
# Out:
# [0, 2, 3, 4]

# %% [markdown]
# # A*

# %%
def aStarAlgo(start_node, stop_node):
    open_set = set(start_node)
    closed_set = set()
    g = {}     # store the distance from starting node          
    parents = {}
    g[start_node] = 0                         
    parents[start_node] = start_node
    while len(open_set) > 0:
        n = None            #holding node with less f(n)
        for v in open_set:
            if n == None or g[v] + heuristic(v) < g[n] + heuristic(n):
                n = v
        if n == stop_node or Graph_nodes[n] == None:
            pass
        else:
            for (m, weight) in get_neighbors(n):
                if m not in open_set and m not in closed_set:
                    open_set.add(m)
                    parents[m] = n
                    g[m] = g[n] + weight
                   
                    
                else:
                    if g[m] > g[n] + weight:
                       
    
                        g[m] = g[n] + weight
                       
                        parents[m] = n
                        if m in closed_set:
                            closed_set.remove(m)
                            open_set.add(m)
        if n == None:
            print('Path does not exist!')
            return None
        if n == stop_node:
            path = []
            while parents[n] != n:
                path.append(n)
                n = parents[n]
            path.append(start_node)
            path.reverse()
            print('Path: {}'.format(path))
            return path
        open_set.remove(n)
        closed_set.add(n)
    print('Path does not exist!')
    return None

def get_neighbors(v):
    if v in Graph_nodes:
        return Graph_nodes[v]
    else:
        return None
def heuristic(n):
    H_dist = {
        'A': 11,
        'B': 6,
        'C': 99,
        'D': 1,
        'E': 7,
        'G': 0,
    }
    return H_dist[n]

Graph_nodes = {
    'A': [('B', 2), ('E', 3)],
    'B': [('A', 2), ('C', 1), ('G', 9)],
    'C': [('B', 1)],
    'D': [('E', 6), ('G', 1)],
    'E': [('A', 3), ('D', 6)],
    'G': [('B', 9), ('D', 1)]
}

aStarAlgo('A', 'G')
# Out:
# Path: ['A', 'E', 'D', 'G']
# ['A', 'E', 'D', 'G']

# %% [markdown]
# # 8 Puzzle

# %%
import copy
from queue import PriorityQueue
def hue(A,B):
    x = 0
    
    for i in range(3):
        for j in range(3):
            if(A[i][j] != B[i][j]):
              x = x +1

def path(A,B,H,movements):
    k = []
    pq = PriorityQueue()
    pq.put((0,A,'init'))
    if A not in k:
        k.append(A)
        
    while pq.empty() == False:
        y = pq.get()
        u = y[1]
        movements.append(y[2])
        print(u)
        
        r = 0                
        c = 0
        
        for i in range(3):
            for j in range(3):
                if(u[i][j]==0):               
                    r = i
                    c = j
                    
        R = 3
        C = 3
        z = 0
        C1 = copy.deepcopy(u)               
        C2 = copy.deepcopy(u)
        C3 = copy.deepcopy(u)
        C4 = copy.deepcopy(u)
        
        if hue(u,B) == 0:                   
            print("Goal reached")               
            print(movements)
            break
        else:
            if((r-1 >= 0)):                
                t1 = C1[r-1][c]           
                C1[r-1][c] = 0             
                C1[r][c] = t1
                h1 = hue(C1,B)                   
                if C1 not in k:               
                    pq.put((h1,C1,'up'))
                    k.append(C1)
                    
            if((r+1 < 3)):
                t2 = C2[r+1][c]
                C2[r+1][c] = 0
                C2[r][c] = t2
                h2 = hue(C2,B)
                if C2 not in k:
                    pq.put((h2,C2,'down'))
                    k.append(C2)
                    
            if((c-1>=0)):
                t3 = C3[r][c-1]
                C3[r][c-1] = 0
                C3[r][c] = t3
                h3 = hue(C3,B)
                if C3 not in k:
                    pq.put((h3,C3,'left'))
                    k.append(C3)
                    
            if((c+1<3)):
                t4 = C4[r][c+1]
                C4[r][c+1] = 0
                C4[r][c] = t4
                h4 = hue(C4,B)
                if C4 not in k:
                    pq.put((h4,C4,'right'))
                    k.append(C4)
                    
S = [[1,2,3],
     [4,5,8],
     [7,6,0]]

D = [[1,2,3],
     [8,0,4],
     [7,6,5]]
h = hue(S,D)
print(h)
movements = []
if(h==0):
    print(S)
else:
    path(S,D,h,movements)
# Out:
# None
# [[1, 2, 3], [4, 5, 8], [7, 6, 0]]
# [[1, 2, 3], [4, 5, 0], [7, 6, 8]]
# [[1, 2, 0], [4, 5, 3], [7, 6, 8]]
# [[1, 0, 2], [4, 5, 3], [7, 6, 8]]
# [[0, 1, 2], [4, 5, 3], [7, 6, 8]]
# [[1, 2, 3], [4, 0, 5], [7, 6, 8]]
# [[1, 0, 3], [4, 2, 5], [7, 6, 8]]
# [[0, 1, 3], [4, 2, 5], [7, 6, 8]]
# [[1, 2, 3], [0, 4, 5], [7, 6, 8]]
# [[0, 2, 3], [1, 4, 5], [7, 6, 8]]
# [[1, 2, 3], [4, 5, 8], [7, 0, 6]]
# [[1, 2, 3], [4, 0, 8], [7, 5, 6]]
# [[1, 0, 3], [4, 2, 8], [7, 5, 6]]
# [[0, 1, 3], [4, 2, 8], [7, 5, 6]]
# [[1, 2, 3], [0, 4, 8], [7, 5, 6]]
# [[0, 2, 3], [1, 4, 8], [7, 5, 6]]
# [[1, 2, 3], [4, 5, 8], [0, 7, 6]]
# [[1, 2, 3], [0, 5, 8], [4, 7, 6]]
# [[0, 2, 3], [1, 5, 8], [4, 7, 6]]
# [[1, 2, 3], [4, 6, 5], [7, 0, 8]]
# [[1, 2, 3], [4, 6, 5], [0, 7, 8]]
# [[1, 2, 3], [0, 6, 5], [4, 7, 8]]
# [[0, 2, 3], [1, 6, 5], [4, 7, 8]]
# [[1, 2, 3], [4, 6, 5], [7, 8, 0]]
# [[1, 2, 3], [4, 6, 0], [7, 8, 5]]
# [[1, 2, 0], [4, 6, 3], [7, 8, 5]]
# [[1, 0, 2], [4, 6, 3], [7, 8, 5]]
# ...
